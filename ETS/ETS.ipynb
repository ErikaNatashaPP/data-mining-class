# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
data = pd.read_csv('online_retail.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null object
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/11 12:50       0.85     12680.0  France
# 541905  12/9/11 12:50       2.10     12680.0  France
# 541906  12/9/11 12:50       4.15     12680.0  France
# 541907  12/9/11 12:50       4.15     12680.0  France
# 541908  12/9/11 12:50       4.95     12680.0  France

# %%
gp_invoiceno = data.groupby('InvoiceNo')
transactions = []
for name,group in gp_invoiceno:
    transactions.append(list(group['Description'].map(str)))

# %%
rules = apriori(transactions, min_support = 0.005, min_confidence = 0.2, min_lift = 3, min_length = 2)
results = list(rules)

# %% [markdown]
# ## MAXIM

# %%
final_results = pd.DataFrame(np.random.randint(low=0, high=1, size=(len(results), 6)), columns=['GeneralRules', 'LeftRules', 'RightRules', 'Support', 'Confidence', 'Lift'])
index = 0
for g, s, i in results:
    final_results.iloc[index] = [' _&&_ '.join(list(g)), ' _&&_ '.join(list(i[0][0])), ' _&&_ '.join(list(i[0][1])), s, i[0][2], i[0][3]]
    index = index+1
final_results = final_results.sort_values('Lift', ascending=0)
final_results.head(10)
# Out:
#                                            GeneralRules  \
# 4599  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
# 4626  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
# 4324  HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  ...
# 4598  HERB MARKER THYME _&&_ HERB MARKER CHIVES  _&&...
# 4332  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...
# 4319  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...
# 4601  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
# 4600  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
# 4331  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...
# 4323  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...
#
#                                               LeftRules           RightRules  \
# 4599  HERB MARKER PARSLEY _&&_ HERB MARKER ROSEMARY ...    HERB MARKER THYME
# 4626  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...    HERB MARKER THYME
# 4324  HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  ...    HERB MARKER THYME
# 4598  HERB MARKER MINT _&&_ HERB MARKER ROSEMARY _&&...    HERB MARKER THYME
# 4332  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...    HERB MARKER THYME
# 4319  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...  HERB MARKER PARSLEY
# 4601  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...    HERB MARKER THYME
# 4600  HERB MARKER MINT _&&_ HERB MARKER ROSEMARY _&&...    HERB MARKER THYME
# 4331  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...    HERB MARKER THYME
# 4323  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...    HERB MARKER THYME
#
#        Support  Confidence        Lift
# 4599  0.006409    0.988095  107.528011
# 4626  0.006100    0.987500  107.463235
# 4324  0.006525    0.982558  106.925445
# 4598  0.006139    0.981481  106.808279
# 4332  0.006911    0.972826  105.866368
# 4319  0.006448    0.976608  105.833272
# 4601  0.006564    0.971429  105.714286
# 4600  0.006680    0.966480  105.175813
# 4331  0.006641    0.966292  105.155321
# 4323  0.006564    0.965909  105.113636

# %%
count=1
for i, d in final_results.head(20).iterrows():
    print('Rule #'+str(count)+':')
    print(d['LeftRules'])
    print('=> '+d['RightRules'])
    print('Support: '+str(d['Support'])+' - Confidence: '+str(d['Confidence'])+' - Lift: '+str(d['Lift']))
    print('--------------------')
    count=count+1
# Out:
# Rule #1:
# HERB MARKER PARSLEY _&&_ HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.006409266409266409 - Confidence: 0.9880952380952381 - Lift: 107.5280112044818
# --------------------
# Rule #2:
# HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER MINT _&&_ HERB MARKER BASIL _&&_ HERB MARKER ROSEMARY
# => HERB MARKER THYME
# Support: 0.006100386100386101 - Confidence: 0.9875 - Lift: 107.46323529411765
# --------------------
# Rule #3:
# HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.0065250965250965255 - Confidence: 0.9825581395348838 - Lift: 106.92544459644324
# --------------------
# Rule #4:
# HERB MARKER MINT _&&_ HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.006138996138996139 - Confidence: 0.9814814814814815 - Lift: 106.8082788671024
# --------------------
# Rule #5:
# HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER ROSEMARY
# => HERB MARKER THYME
# Support: 0.006911196911196911 - Confidence: 0.9728260869565217 - Lift: 105.86636828644501
# --------------------
# Rule #6:
# HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER PARSLEY
# Support: 0.006447876447876448 - Confidence: 0.9766081871345029 - Lift: 105.83327216227458
# --------------------
# Rule #7:
# HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER ROSEMARY _&&_ HERB MARKER PARSLEY
# => HERB MARKER THYME
# Support: 0.006563706563706564 - Confidence: 0.9714285714285714 - Lift: 105.71428571428572
# --------------------
# Rule #8:
# HERB MARKER MINT _&&_ HERB MARKER ROSEMARY _&&_ HERB MARKER BASIL _&&_ HERB MARKER PARSLEY
# => HERB MARKER THYME
# Support: 0.006679536679536679 - Confidence: 0.9664804469273743 - Lift: 105.17581334209662
# --------------------
# Rule #9:
# HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER ROSEMARY
# => HERB MARKER THYME
# Support: 0.006640926640926641 - Confidence: 0.9662921348314607 - Lift: 105.15532055518837
# --------------------
# Rule #10:
# HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.006563706563706564 - Confidence: 0.9659090909090909 - Lift: 105.11363636363637
# --------------------
# Rule #11:
# HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL _&&_ HERB MARKER PARSLEY
# => HERB MARKER THYME
# Support: 0.006216216216216216 - Confidence: 0.9640718562874252 - Lift: 104.91370200774921
# --------------------
# Rule #12:
# HERB MARKER CHIVES  _&&_ HERB MARKER ROSEMARY
# => HERB MARKER THYME
# Support: 0.007065637065637066 - Confidence: 0.9631578947368421 - Lift: 104.81424148606811
# --------------------
# Rule #13:
# SET/6 COLLAGE PAPER CUPS
# => SET/6 COLLAGE PAPER PLATES
# Support: 0.0062548262548262545 - Confidence: 0.8901098901098901 - Lift: 104.79020979020977
# --------------------
# Rule #14:
# PACK OF 6 SKULL PAPER CUPS
# => PACK OF 6 SKULL PAPER PLATES
# Support: 0.0052123552123552125 - Confidence: 0.7803468208092486 - Lift: 104.72011740393542
# --------------------
# Rule #15:
# HERB MARKER MINT _&&_ HERB MARKER CHIVES
# => HERB MARKER PARSLEY
# Support: 0.007104247104247104 - Confidence: 0.9633507853403142 - Lift: 104.39659138206753
# --------------------
# Rule #16:
# HERB MARKER PARSLEY _&&_ HERB MARKER ROSEMARY _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.00722007722007722 - Confidence: 0.958974358974359 - Lift: 104.35897435897436
# --------------------
# Rule #17:
# HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER PARSLEY
# Support: 0.006795366795366796 - Confidence: 0.9617486338797815 - Lift: 104.22296911082151
# --------------------
# Rule #18:
# HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.006293436293436294 - Confidence: 0.9532163742690059 - Lift: 103.73237014103887
# --------------------
# Rule #19:
# HERB MARKER CHIVES  _&&_ HERB MARKER BASIL
# => HERB MARKER THYME
# Support: 0.006718146718146718 - Confidence: 0.9508196721311475 - Lift: 103.47155255544841
# --------------------
# Rule #20:
# DOLLY GIRL CHILDRENS BOWL
# => DOLLY GIRL CHILDRENS CUP
# Support: 0.005945945945945946 - Confidence: 0.7897435897435897 - Lift: 103.3048433048433
# --------------------

# %%
final_results = pd.DataFrame(np.random.randint(low=0, high=1, size=(len(results), 6)), columns=['GeneralRules', 'LeftRules', 'RightRules', 'Support', 'Confidence', 'Lift'])
index = 0
for g, s, i in results:
    final_results.iloc[index] = [' _&&_ '.join(list(g)), ' _&&_ '.join(list(i[0][0])), ' _&&_ '.join(list(i[0][1])), s, i[0][2], i[0][3]]
    index = index+1
final_results = final_results.sort_values('Confidence', ascending=0)
final_results.head(10)
# Out:
#                                            GeneralRules  \
# 188   DOTCOM POSTAGE _&&_ BEADED CRYSTAL HEART GREEN...
# 4599  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
# 4626  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
# 2469  BEADED CRYSTAL HEART PINK ON STICK _&&_ DOTCOM...
# 4324  HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  ...
# 4598  HERB MARKER THYME _&&_ HERB MARKER CHIVES  _&&...
# 4319  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...
# 189   BEADED CRYSTAL HEART PINK ON STICK _&&_ DOTCOM...
# 4332  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...
# 4601  HERB MARKER THYME _&&_ HERB MARKER PARSLEY _&&...
#
#                                               LeftRules           RightRules  \
# 188                 BEADED CRYSTAL HEART GREEN ON STICK       DOTCOM POSTAGE
# 4599  HERB MARKER PARSLEY _&&_ HERB MARKER ROSEMARY ...    HERB MARKER THYME
# 4626  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...    HERB MARKER THYME
# 2469  BEADED CRYSTAL HEART PINK ON STICK _&&_ BEADED...       DOTCOM POSTAGE
# 4324  HERB MARKER ROSEMARY _&&_ HERB MARKER CHIVES  ...    HERB MARKER THYME
# 4598  HERB MARKER MINT _&&_ HERB MARKER ROSEMARY _&&...    HERB MARKER THYME
# 4319  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...  HERB MARKER PARSLEY
# 189                  BEADED CRYSTAL HEART PINK ON STICK       DOTCOM POSTAGE
# 4332  HERB MARKER PARSLEY _&&_ HERB MARKER CHIVES  _...    HERB MARKER THYME
# 4601  HERB MARKER MINT _&&_ HERB MARKER CHIVES  _&&_...    HERB MARKER THYME
#
#        Support  Confidence        Lift
# 188   0.006564    0.988372   36.105553
# 4599  0.006409    0.988095  107.528011
# 4626  0.006100    0.987500  107.463235
# 2469  0.005212    0.985401   35.997035
# 4324  0.006525    0.982558  106.925445
# 4598  0.006139    0.981481  106.808279
# 4319  0.006448    0.976608  105.833272
# 189   0.007761    0.975728   35.643666
# 4332  0.006911    0.972826  105.866368
# 4601  0.006564    0.971429  105.714286

# %%
final_results = pd.DataFrame(np.random.randint(low=0, high=1, size=(len(results), 6)), columns=['GeneralRules', 'LeftRules', 'RightRules', 'Support', 'Confidence', 'Lift'])
index = 0
for g, s, i in results:
    final_results.iloc[index] = [' _&&_ '.join(list(g)), ' _&&_ '.join(list(i[0][0])), ' _&&_ '.join(list(i[0][1])), s, i[0][2], i[0][3]]
    index = index+1
final_results = final_results.sort_values('Support', ascending=0)
final_results.head(10)
# Out:
#                                            GeneralRules  \
# 1256  JUMBO BAG PINK POLKADOT _&&_ JUMBO BAG RED RET...
# 822   ROSES REGENCY TEACUP AND SAUCER  _&&_ GREEN RE...
# 1321  JUMBO STORAGE BAG SUKI _&&_ JUMBO BAG RED RETR...
# 1319  JUMBO SHOPPER VINTAGE RED PAISLEY _&&_ JUMBO B...
# 1611  LUNCH BAG  BLACK SKULL. _&&_ LUNCH BAG RED RET...
# 104   ALARM CLOCK BAKELIKE RED  _&&_ ALARM CLOCK BAK...
# 811   PINK REGENCY TEACUP AND SAUCER _&&_ GREEN REGE...
# 2024  PINK REGENCY TEACUP AND SAUCER _&&_ ROSES REGE...
# 1698  LUNCH BAG RED RETROSPOT _&&_ LUNCH BAG PINK PO...
# 1081  JUMBO  BAG BAROQUE BLACK WHITE _&&_ JUMBO BAG ...
#
#                             LeftRules                         RightRules  \
# 1256          JUMBO BAG PINK POLKADOT            JUMBO BAG RED RETROSPOT
# 822   GREEN REGENCY TEACUP AND SAUCER   ROSES REGENCY TEACUP AND SAUCER
# 1321          JUMBO BAG RED RETROSPOT             JUMBO STORAGE BAG SUKI
# 1319          JUMBO BAG RED RETROSPOT  JUMBO SHOPPER VINTAGE RED PAISLEY
# 1611          LUNCH BAG  BLACK SKULL.            LUNCH BAG RED RETROSPOT
# 104        ALARM CLOCK BAKELIKE GREEN          ALARM CLOCK BAKELIKE RED
# 811   GREEN REGENCY TEACUP AND SAUCER     PINK REGENCY TEACUP AND SAUCER
# 2024   PINK REGENCY TEACUP AND SAUCER   ROSES REGENCY TEACUP AND SAUCER
# 1698          LUNCH BAG PINK POLKADOT            LUNCH BAG RED RETROSPOT
# 1081   JUMBO  BAG BAROQUE BLACK WHITE            JUMBO BAG RED RETROSPOT
#
#        Support  Confidence       Lift
# 1256  0.032162    0.676686   8.208973
# 822   0.030270    0.741722  17.152318
# 1321  0.028301    0.343326   7.403939
# 1319  0.026371    0.319906   6.980264
# 1611  0.025019    0.500386   8.064717
# 104   0.024942    0.645355  15.462244
# 811   0.024865    0.609272  19.700540
# 2024  0.023707    0.766542  17.726280
# 1698  0.023668    0.552252   8.900643
# 1081  0.022896    0.626188   7.596379

# %% [markdown]
# ## MINIM

# %%
final_results = pd.DataFrame(np.random.randint(low=0, high=1, size=(len(results), 6)), columns=['GeneralRules', 'LeftRules', 'RightRules', 'Support', 'Confidence', 'Lift'])
index = 0
for g, s, i in results:
    final_results.iloc[index] = [' _&&_ '.join(list(g)), ' _&&_ '.join(list(i[0][0])), ' _&&_ '.join(list(i[0][1])), s, i[0][2], i[0][3]]
    index = index+1
final_results = final_results.sort_values('Lift')
final_results.head(10)
# Out:
#                                            GeneralRules  \
# 994   IVORY KITCHEN SCALES _&&_ REGENCY CAKESTAND 3 ...
# 2177  REGENCY CAKESTAND 3 TIER _&&_ SET OF 3 BUTTERF...
# 47    60 CAKE CASES VINTAGE CHRISTMAS _&&_ JUMBO BAG...
# 34    WHITE HANGING HEART T-LIGHT HOLDER _&&_ 6 RIBB...
# 1020  REGENCY CAKESTAND 3 TIER _&&_ JAM MAKING SET P...
# 1356  JUMBO BAG RED RETROSPOT _&&_ RECIPE BOX PANTRY...
# 2739  WHITE HANGING HEART T-LIGHT HOLDER _&&_ RED RE...
# 1343  PACK OF 72 RETROSPOT CAKE CASES _&&_ JUMBO BAG...
# 25    REGENCY CAKESTAND 3 TIER _&&_ 6 RIBBONS RUSTIC...
# 2053  PLEASE ONE PERSON METAL SIGN _&&_ WHITE HANGIN...
#
#                                               LeftRules  \
# 994                                IVORY KITCHEN SCALES
# 2177                  SET OF 3 BUTTERFLY COOKIE CUTTERS
# 47                      60 CAKE CASES VINTAGE CHRISTMAS
# 34                               6 RIBBONS RUSTIC CHARM
# 1020                             JAM MAKING SET PRINTED
# 1356                    RECIPE BOX PANTRY YELLOW DESIGN
# 2739  RED RETROSPOT CHARLOTTE BAG _&&_ CHARLOTTE BAG...
# 1343                    PACK OF 72 RETROSPOT CAKE CASES
# 25                               6 RIBBONS RUSTIC CHARM
# 2053                       PLEASE ONE PERSON METAL SIGN
#
#                               RightRules   Support  Confidence      Lift
# 994             REGENCY CAKESTAND 3 TIER  0.007027    0.251381  3.001740
# 2177            REGENCY CAKESTAND 3 TIER  0.006757    0.251437  3.002403
# 47               JUMBO BAG RED RETROSPOT  0.005946    0.247588  3.003532
# 34    WHITE HANGING HEART T-LIGHT HOLDER  0.009923    0.267430  3.008875
# 1020            REGENCY CAKESTAND 3 TIER  0.011429    0.252129  3.010675
# 1356             JUMBO BAG RED RETROSPOT  0.011158    0.248282  3.011943
# 2739  WHITE HANGING HEART T-LIGHT HOLDER  0.005290    0.268627  3.022351
# 1343             JUMBO BAG RED RETROSPOT  0.012857    0.249625  3.028240
# 25              REGENCY CAKESTAND 3 TIER  0.009421    0.253902  3.031843
# 2053  WHITE HANGING HEART T-LIGHT HOLDER  0.008919    0.270175  3.039767

# %%
final_results = pd.DataFrame(np.random.randint(low=0, high=1, size=(len(results), 6)), columns=['GeneralRules', 'LeftRules', 'RightRules', 'Support', 'Confidence', 'Lift'])
index = 0
for g, s, i in results:
    final_results.iloc[index] = [' _&&_ '.join(list(g)), ' _&&_ '.join(list(i[0][0])), ' _&&_ '.join(list(i[0][1])), s, i[0][2], i[0][3]]
    index = index+1
final_results = final_results.sort_values('Confidence')
final_results.head(10)
# Out:
#                                            GeneralRules  \
# 1774  STRAWBERRY CHARLOTTE BAG _&&_ LUNCH BAG SPACEB...
# 1775  WOODLAND CHARLOTTE BAG _&&_ LUNCH BAG SPACEBOY...
# 1416  JUMBO BAG SCANDINAVIAN BLUE PAISLEY _&&_ PAPER...
# 1135    JUMBO BAG ALPHABET _&&_ LUNCH BAG  BLACK SKULL.
# 1317  JUMBO BAG VINTAGE LEAF _&&_ JUMBO BAG RED RETR...
# 761   GARDENERS KNEELING PAD CUP OF TEA  _&&_ PAPER ...
# 771   GARDENERS KNEELING PAD KEEP CALM  _&&_ POPCORN...
# 408   RECYCLING BAG RETROSPOT  _&&_ CHARLOTTE BAG SU...
# 989    IVORY KITCHEN SCALES _&&_ JAM MAKING SET PRINTED
# 645    RECORD FRAME 7" SINGLE SIZE  _&&_ DOTCOM POSTAGE
#
#                                 LeftRules                       RightRules  \
# 1774           LUNCH BAG SPACEBOY DESIGN          STRAWBERRY CHARLOTTE BAG
# 1775           LUNCH BAG SPACEBOY DESIGN            WOODLAND CHARLOTTE BAG
# 1416  JUMBO BAG SCANDINAVIAN BLUE PAISLEY          PAPER BUNTING RETROSPOT
# 1135                   JUMBO BAG ALPHABET          LUNCH BAG  BLACK SKULL.
# 1317              JUMBO BAG RED RETROSPOT           JUMBO BAG VINTAGE LEAF
# 761    GARDENERS KNEELING PAD CUP OF TEA   PAPER CHAIN KIT 50'S CHRISTMAS
# 771     GARDENERS KNEELING PAD KEEP CALM                    POPCORN HOLDER
# 408             CHARLOTTE BAG SUKI DESIGN         RECYCLING BAG RETROSPOT
# 989                  IVORY KITCHEN SCALES           JAM MAKING SET PRINTED
# 645                        DOTCOM POSTAGE     RECORD FRAME 7" SINGLE SIZE
#
#        Support  Confidence       Lift
# 1774  0.009035    0.200000   7.057221
# 1775  0.009035    0.200000   6.144721
# 1416  0.005174    0.200000   6.426799
# 1135  0.007104    0.200000   4.000000
# 1317  0.016486    0.200000   5.853107
# 761   0.005907    0.200000   4.427350
# 771   0.007143    0.200216   6.180699
# 408   0.006911    0.200224   6.886845
# 989   0.005598    0.200276   4.418360
# 645   0.005483    0.200282  14.211797

# %%
final_results = pd.DataFrame(np.random.randint(low=0, high=1, size=(len(results), 6)), columns=['GeneralRules', 'LeftRules', 'RightRules', 'Support', 'Confidence', 'Lift'])
index = 0
for g, s, i in results:
    final_results.iloc[index] = [' _&&_ '.join(list(g)), ' _&&_ '.join(list(i[0][0])), ' _&&_ '.join(list(i[0][1])), s, i[0][2], i[0][3]]
    index = index+1
final_results = final_results.sort_values('Support')
final_results.head(10)
# Out:
#                                            GeneralRules  \
# 444   LUNCH BAG  BLACK SKULL. _&&_ CHILDRENS APRON S...
# 1929  VINTAGE HEADS AND TAILS CARD GAME  _&&_ PACK O...
# 1935  PACK OF 72 SKULL CAKE CASES _&&_ SET OF 60 PAN...
# 1114  JUMBO BAG 50'S CHRISTMAS  _&&_ ROLL WRAP 50'S ...
# 1705  PINK VINTAGE PAISLEY PICNIC BAG _&&_ LUNCH BAG...
# 3609  LUNCH BAG APPLE DESIGN _&&_ LUNCH BAG  BLACK S...
# 3636  WHITE HANGING HEART T-LIGHT HOLDER _&&_ PACK O...
# 1556  LUNCH BOX WITH CUTLERY RETROSPOT  _&&_ JUMBO S...
# 1981  PAPER CHAIN KIT VINTAGE CHRISTMAS _&&_ ZINC FO...
# 2652  LUNCH BAG RED RETROSPOT _&&_ CHARLOTTE BAG SUK...
#
#                                               LeftRules  \
# 444                     CHILDRENS APRON SPACEBOY DESIGN
# 1929                 VINTAGE HEADS AND TAILS CARD GAME
# 1935                SET OF 60 PANTRY DESIGN CAKE CASES
# 1114                           ROLL WRAP 50'S CHRISTMAS
# 1705                    PINK VINTAGE PAISLEY PICNIC BAG
# 3609  LUNCH BAG  BLACK SKULL. _&&_ JUMBO BAG RED RET...
# 3636  PACK OF 72 RETROSPOT CAKE CASES _&&_ JUMBO BAG...
# 1556                  LUNCH BOX WITH CUTLERY RETROSPOT
# 1981                          ZINC FOLKART SLEIGH BELLS
# 2652  CHARLOTTE BAG SUKI DESIGN _&&_ CHARLOTTE BAG V...
#
#                               RightRules   Support  Confidence       Lift
# 444              LUNCH BAG  BLACK SKULL.  0.005019    0.230906   4.618117
# 1929     PACK OF 72 RETROSPOT CAKE CASES  0.005019    0.212766   4.130913
# 1935         PACK OF 72 SKULL CAKE CASES  0.005019    0.205047   7.998081
# 1114           JUMBO BAG 50'S CHRISTMAS   0.005019    0.364146  13.044775
# 1705             LUNCH BAG PINK POLKADOT  0.005019    0.314010   7.326892
# 3609              LUNCH BAG APPLE DESIGN  0.005019    0.338542   8.358655
# 3636  WHITE HANGING HEART T-LIGHT HOLDER  0.005019    0.390390   4.392316
# 1556              JUMBO STORAGE BAG SUKI  0.005019    0.264766   5.709770
# 1981   PAPER CHAIN KIT VINTAGE CHRISTMAS  0.005019    0.281385   8.759470
# 2652             LUNCH BAG RED RETROSPOT  0.005019    0.528455   8.517108
