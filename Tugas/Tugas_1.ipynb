# %%
import pandas as pd
import numpy as np
BBBT=pd.read_csv('D:\DataSurvey.csv',sep=";")
IPS=pd.read_csv('D:\DS2.csv', sep=";")
BBBT
# Out:
#            NRP  BERAT BADAN (KG) TINGGI BADAN (CM)
# 0   3113100066                57               155
# 1   3113100090                40               150
# 2   3113100106                48               157
# 3   3113100007                86               172
# 4   3113100107                47               158
# 5   3113100003                51               160
# 6   3113100127                55               168
# 7   3113100073               108               167
# 8   3113100076                65               170
# 9   3113100074                45               152
# 10  3114100138                75               172
# 11  3114100005                55               174
# 12  3114100017                70               170
# 13  3114100092                74               165
# 14  3114100036                46             149,5
# 15  3114100079                50               167
# 16  3114100702                56               170
# ...

# %%
IPS
# Out:
#            NRP IPS SEMESTER GANJIL IPS SEMESTER GENAP
# 0   3113100066                3,58               3,44
# 1   3113100090                3,72                3,4
# 2   3113100106                3,54               3,59
# 3   3113100007                3,89               3,87
# 4   3113100107                3,59               3,55
# 5   3113100003                 3,4                3,7
# 6   3113100127                 3,4                3,4
# 7   3113100073                3,63                3,5
# 8   3113100076                3,92               3,74
# 9   3113100074                 3,9                3,8
# 10  3114100138                 3,6                3,4
# 11  3114100005                 3,3               3,28
# 12  3114100017                 3,3                2,9
# 13  3114100092                 3,2                3,2
# 14  3114100036                 3,2                3,2
# 15  3114100079                3,19               3,25
# ...

# %%
# merge data based on ID
data = pd.merge(BBBT, IPS, on='NRP')
data
# Out:
#            NRP  BERAT BADAN (KG) TINGGI BADAN (CM) IPS SEMESTER GANJIL  \
# 0   3113100066                57               155                3,58
# 1   3113100090                40               150                3,72
# 2   3113100106                48               157                3,54
# 3   3113100007                86               172                3,89
# 4   3113100107                47               158                3,59
# 5   3113100003                51               160                 3,4
# 6   3113100127                55               168                 3,4
# 7   3113100073               108               167                3,63
# 8   3113100076                65               170                3,92
# 9   3113100074                45               152                 3,9
# 10  3114100138                75               172                 3,6
# 11  3114100005                55               174                 3,3
# ...

# %%
# delete colomn
data1 = data.drop(['IPS SEMESTER GANJIL'], axis=1)
data1
# Out:
#            NRP  BERAT BADAN (KG) TINGGI BADAN (CM) IPS SEMESTER GENAP
# 0   3113100066                57               155               3,44
# 1   3113100090                40               150                3,4
# 2   3113100106                48               157               3,59
# 3   3113100007                86               172               3,87
# 4   3113100107                47               158               3,55
# 5   3113100003                51               160                3,7
# 6   3113100127                55               168                3,4
# 7   3113100073               108               167                3,5
# 8   3113100076                65               170               3,74
# 9   3113100074                45               152                3,8
# 10  3114100138                75               172                3,4
# 11  3114100005                55               174               3,28
# ...

# %%
# Drop baris ke-4
data2 = data.drop([3])
data2
# Out:
#            NRP  BERAT BADAN (KG) TINGGI BADAN (CM) IPS SEMESTER GANJIL  \
# 0   3113100066                57               155                3,58
# 1   3113100090                40               150                3,72
# 2   3113100106                48               157                3,54
# 4   3113100107                47               158                3,59
# 5   3113100003                51               160                 3,4
# 6   3113100127                55               168                 3,4
# 7   3113100073               108               167                3,63
# 8   3113100076                65               170                3,92
# 9   3113100074                45               152                 3,9
# 10  3114100138                75               172                 3,6
# 11  3114100005                55               174                 3,3
# 12  3114100017                70               170                 3,3
# ...
